# %%
import yfinance as yf
import numpy as np
import pandas as pd
import sqlite3

# %%
data = yf.download('GLD', period='1wk', interval='1d').reset_index()
data.columns = data.columns.to_flat_index()
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#     (Date, )  (Close, GLD)  (High, GLD)  (Low, GLD)  (Open, GLD)  \
# 0 2026-08-31    408.420013   408.799988  404.899994   407.760010
# 1 2026-09-01    396.750000   401.250000  396.450012   398.290009
# 2 2026-09-02    402.779999   403.329987  399.579987   399.709991
# 3 2026-09-03    410.220001   413.540009  408.540009   410.709991
# 4 2026-09-04    406.769989   408.000000  403.959991   404.660004
#
#    (Volume, GLD)
# 0        9490000
# 1       13143000
# 2       13714100
# 3       12509500
# 4        9813200

# %%
data.columns
# Out:
# Index([     ('Date', ''),  ('Close', 'GLD'),   ('High', 'GLD'),
#           ('Low', 'GLD'),   ('Open', 'GLD'), ('Volume', 'GLD')],
#       dtype='object')
